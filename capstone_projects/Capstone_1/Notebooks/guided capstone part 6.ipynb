# %% [markdown]
# # Guided Capstone Findings:
# ___

# %% [markdown]
# ## 1. Are Big Mountain's ticket prices underpriced relative to the market?

# %% [markdown]
# ![AdultWeekend.png](attachment:AdultWeekend.png)

# %% [markdown]
# ![Montana%20prices.png](attachment:Montana%20prices.png)

# %% [markdown]
# ### Building two models to predict price, a Linear Regression and a Random Forest model:
#
# With final best model MAEs (after Cross Validation):
#
#     Linear Regression MAE:     11.79
#     Random Forest MAE:        9.54
#
#
# Random Forest has a lower error and less variable (more consistent) cross validation performance. Random Forest will be the model used to predict price.
#
#
# ### Model Fitting/Prediction:
#
#
# #### Current Resort Price: 81 dollars
#
# #### Model Suggested Price: 95.87 dollars
#
# Top Six | Dominant Features
# :-- | :--
# fastQuads|Snow-making area
# Vertical drop|Runs
# Total Runs|Skiable area

# %% [markdown]
# ## 2. Alternate scenario: Close up to 10 of the least used runs. (assuming total tickets sales of 1.75 mil)

# %% [markdown]
# The cost of closing one run in terms of lost revenue is 0.
# The cost of closing 3-5 runs would be a decrease in revenue of 1,166,666.67 dollars.

# %% [markdown]
# ![scenario1.png](attachment:scenario1.png)

# %% [markdown]
# ## 3. Alternate scenario: Big Mountain is adds a run, increasing the vertical drop by 150 feet, and installing an additional chair lift. (assuming total tickets sales of 1.75 mil)

# %% [markdown]
# Result: Increased support for ticket price by 1.99 dollars.
# Over the season, this could be expected to amount to 3,474,638 dollars additional revenue.

# %% [markdown]
# ## 4. Alternate scenario: Big Mountain is adds a run, increasing the vertical drop by 150 feet, installing an additional chair lift, AND installing 2 additional acres of snow making coverage.

# %% [markdown]
# A small increase of 2 acres of snow-making coverage makes no difference from the previous scenario.

# %% [markdown]
# ## 5. Add .2 miles to lengthen the longest run and add 4 acres snow-making coverage.

# %% [markdown]
# Result: No change in predicted ticket price.
